# %%
import pandas as pd

# %%
DF1 = pd.DataFrame({'Autos':['Nissan','Ford','Audi'],
'Color':['Blanco','Azul','Rojo']})

# %%
DF2 = pd.DataFrame({'Autos':['Toyota','Ford','Audi'],
'Modelo':['2018','2020','2022']})

# %%
DF=pd.merge(DF1,DF2, on='Autos', how='right')

# %%
DF
# Out:
#     Autos   Color Modelo
# 0  Nissan  Blanco   2018
# 1    Ford    Azul   2020
# 2    Audi    Rojo   2022

# %%
DF
# Out:
#     Autos Color Modelo
# 0  Toyota   NaN   2018
# 1    Ford  Azul   2020
# 2    Audi  Rojo   2022
